# %% [markdown]
# # Load data from files and create nicer plots

# %%
# Imports
from PIL import Image
import matplotlib.pyplot as plt
import torch
import numpy as np
import os
from time import time
from scipy import stats

# %%
# Load matrices
# https://vegibit.com/how-to-save-and-load-numpy-arrays/
samples_grid = np.loadtxt('./data/samples_grid.txt', delimiter=',')
samples_random = np.loadtxt('./data/samples_random.txt', delimiter=',')
samples_lhc = np.loadtxt('./data/samples_lhc.txt', delimiter=',')

iterations_grid = np.loadtxt('./data/iterations_grid.txt', delimiter=',')
iterations_random = np.loadtxt('./data/iterations_random.txt', delimiter=',')
iterations_lhc = np.loadtxt('./data/iterations_lhc.txt', delimiter=',')


# Put to dictionary 
iterations_convergence = {}
iterations_convergence['grid'] = iterations_grid
iterations_convergence['random'] = iterations_random
iterations_convergence['lhc'] = iterations_lhc

# %%
iterations = np.arange(100, 20100, 500)

# PLT setting
plt.rcParams['figure.dpi'] = 400

plt.figure(figsize=(8, 4))
plt.plot(iterations, iterations_convergence['grid'], label='Grid sampling')
plt.plot(iterations, iterations_convergence['random'], label='Random sampling')
plt.plot(iterations, iterations_convergence['lhc'], label='Latin Hypercube')

# TODO: Update axis names

# TODO: Update ylim
plt.xlim([iterations[0],iterations[len(iterations)-1]])
plt.ylim([1.5,1.55])
plt.xticks(iterations[:,2])


plt.xlabel('Iterations')
plt.ylabel('Area')
#plt.title('Area convergence for different number of iterations and sampling techniques')
plt.legend()
plt.grid()
plt.tight_layout()
plt.show()


# plt.plot(iterations, computationtime_grid, label='grid')
# plt.plot(iterations, computationtime_random, label='random')
# plt.plot(iterations, computationtime_lhc, label='lhc')
""" plt.xlabel('Iterations')
plt.ylabel('Computationl time (s)')
plt.title('Computation time for calculating the area convergence for different number of iterations and sampling techniques')
plt.legend()
plt.grid()
plt.tight_layout()
plt.show() """
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\Users\Pablo\Downloads\Stochastic_Simulation-main\Stochastic_Simulation-main\Stochastic_Simulation\plot.ipynb Cell 4 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/Pablo/Downloads/Stochastic_Simulation-main/Stochastic_Simulation-main/Stochastic_Simulation/plot.ipynb#W1sZmlsZQ%3D%3D?line=13'>14</a> plt.xlim([iterations[0],iterations[len(iterations)-1]])
#      <a href='vscode-notebook-cell:/c%3A/Users/Pablo/Downloads/Stochastic_Simulation-main/Stochastic_Simulation-main/Stochastic_Simulation/plot.ipynb#W1sZmlsZQ%3D%3D?line=14'>15</a> plt.ylim([1.5,1.55])
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Pablo/Downloads/Stochastic_Simulation-main/Stochastic_Simulation-main/Stochastic_Simulation/plot.ipynb#W1sZmlsZQ%3D%3D?line=15'>16</a> plt.xticks(iterations[:,2])
#      <a href='vscode-notebook-cell:/c%3A/Users/Pablo/Downloads/Stochastic_Simulation-main/Stochastic_Simulation-main/Stochastic_Simulation/plot.ipynb#W1sZmlsZQ%3D%3D?line=18'>19</a> plt.xlabel('Iterations')
#      <a href='vscode-notebook-cell:/c%3A/Users/Pablo/Downloads/Stochastic_Simulation-main/Stochastic_Simulation-main/Stochastic_Simulation/plot.ipynb#W1sZmlsZQ%3D%3D?line=19'>20</a> plt.ylabel('Area')
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed
